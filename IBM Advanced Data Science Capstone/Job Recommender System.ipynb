# %% [markdown]
# ### In this project, I will be building a recommender system of new york city job posting using machine learning techniques learned in second course in this specialization. Then next I will be using neural network to improve the model performance. The dataset is obtained from Kaggle, https://www.kaggle.com/new-york-city/new-york-city-current-job-postings.
#
# This dataset contains current job postings available on the City of New York’s official jobs site (http://www.nyc.gov/html/careers/html/search/search.shtml). Internal postings available to city employees and external postings available to the general public are included. This is a dataset hosted by the City of New York. The city has an open data platform found here and they update their information according the amount of data that is brought in. Update Frequency: This dataset is updated weekly.

# %%
# Download the csv file
# !wget https://raw.githubusercontent.com/dxljack/Advanced-Data-Science-with-IBM-Specialization/master/IBM%20Advanced%20Data%20Science%20Capstone/nyc-jobs.csv
# Out:
# Waiting for a Spark session to start...
# Spark Initialization Done! ApplicationId = app-20190924055213-0003
# KERNEL_ID = 2b98ec4c-4818-46a8-a29a-d82f350a20ac
# --2019-09-24 05:52:16--  https://raw.githubusercontent.com/dxljack/Advanced-Data-Science-with-IBM-Specialization/master/IBM%20Advanced%20Data%20Science%20Capstone/nyc-jobs.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 199.232.8.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|199.232.8.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17412646 (17M) [text/plain]
# Saving to: 'nyc-jobs.csv.3'
#
# 100%[======================================>] 17,412,646  78.7MB/s   in 0.2s
#
# 2019-09-24 05:52:17 (78.7 MB/s) - 'nyc-jobs.csv.3' saved [17412646/17412646]

# %%
# Read the csv file in spark
rdd = sc.textFile('nyc-jobs.csv')
df = spark.read.csv(rdd, header=True)

# %% [markdown]
# ### 1. Data Exploration

# %%
# Take a look at our dataset the first time
df.show()
# Out:
# +------+--------------------+------------+--------------+--------------------+--------------------+-------------+-----+--------------------+-----------------------------+-----------------+---------------+----------------+--------------------+--------------------+--------------------+-------------------------+--------------------+----------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+--------------------+
# |Job ID|              Agency|Posting Type|# Of Positions|      Business Title| Civil Service Title|Title Code No|Level|        Job Category|Full-Time/Part-Time indicator|Salary Range From|Salary Range To|Salary Frequency|       Work Location|  Division/Work Unit|     Job Description|Minimum Qual Requirements|    Preferred Skills|Additional Information|            To Apply|         Hours/Shift|     Work Location 1| Recruitment Contact|Residency Requirement|        Posting Date|          Post Until|     Posting Updated|        Process Date|
# +------+--------------------+------------+--------------+--------------------+--------------------+-------------+-----+--------------------+-----------------------------+-----------------+---------------+----------------+--------------------+--------------------+--------------------+-------------------------+--------------------+----------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+--------------------+
# | 87990|DEPARTMENT OF BUS...|    Internal|             1|     Account Manager|CONTRACT REVIEWER...|        40563|    1|                null|                         null|            42405|          65485|          Annual| 110 William St. N Y|Strategy & Analytics|Division of Econo...|     "1.	A baccalaurea...| all candidates m...|  â€¢	Excellent int...|Salary range for ...|                null|                null|                null|                 null|New York City res...|2011-06-24T00:00:...|                null|2011-06-24T00:00:...|
# | 97899|DEPARTMENT OF BUS...|    Internal|             1|EXECUTIVE DIRECTO...|ADMINISTRATIVE BU...|        10009|   M3|                null|                            F|            60740|         162014|          Annual| 110 William St. N Y|Tech Talent Pipeline|The New York City...|     "1. A baccalaurea...|                null|                  null|In addition to ap...|                null|                null|                null| New York City res...|2012-01-26T00:00:...|                null|2012-01-26T00:00:...|2019-08-20T00:00:...|
# |132292|NYC HOUSING AUTHO...|    Internal|            52|Maintenance Worke...|  MAINTENANCE WORKER|        90698|    0|Maintenance & Ope...|                            F|         51907.68|       54580.32|          Annual|Heating Mgt-Opera...|Management Servic...|Under direct supe...|     "1. Three years o...|          mechanical|   or construction ...| may be substitut...| all candidates m...|1.  A High School...|1.  A Motor Vehic...| "Click the ""Appl...|                null|                null|                null|NYCHA has no resi...|
# |132292|NYC HOUSING AUTHO...|    External|            52|Maintenance Worke...|  MAINTENANCE WORKER|        90698|    0|Maintenance & Ope...|                            F|         51907.68|       54580.32|          Annual|Heating Mgt-Opera...|Management Servic...|Under direct supe...|     "1. Three years o...|          mechanical|   or construction ...| may be substitut...| all candidates m...|1.  A High School...|1.  A Motor Vehic...| "Click the ""Appl...|                null|                null|                null|NYCHA has no resi...|
# |133921|NYC HOUSING AUTHO...|    Internal|            50|   Temporary Painter|             PAINTER|        91830|    0|Maintenance & Ope...|                            F|               35|             35|          Hourly|DMP-Contract & An...|Dept of Managemen...|Responsibilities ...|     1. Five years of ...|                null|  SPECIAL NOTE:    ...|"Click the ""Appl...|                null|                null|                null| NYCHA has no resi...|2014-01-09T00:00:...|                null|2014-01-08T00:00:...|2019-08-20T00:00:...|
# |133921|NYC HOUSING AUTHO...|    External|            50|   Temporary Painter|             PAINTER|        91830|    0|Maintenance & Ope...|                            F|               35|             35|          Hourly|DMP-Contract & An...|Dept of Managemen...|Responsibilities ...|     1. Five years of ...|                null|  SPECIAL NOTE:    ...|"Click the ""Appl...|                null|                null|                null| NYCHA has no resi...|2014-01-09T00:00:...|                null|2014-01-08T00:00:...|2019-08-20T00:00:...|
# |137433|DEPT OF HEALTH/ME...|    Internal|             1|    Contract Analyst| PROCUREMENT ANALYST|        12158|    3|Finance, Accounti...|                            F|            50598|          85053|          Annual|   42-09 28th Street|  HIV Administration|** OPEN TO PERMAN...|     "1. A baccalaurea...| individuals must...|   after meeting th...| either one year ...| at least one yea...| or spent perform...|Strong analytical...|                 null|Apply online with...|                null|42-09 28th Street...|                null|
# |138531|DEPT OF ENVIRONME...|    Internal|             1|   Associate Chemist|   ASSOCIATE CHEMIST|        21822|    2|Health Public Saf...|                            F|            50623|          75083|          Annual|96-05 Horace Hard...|    DWOC Labs-Lefrak|Working in the Di...|     Qualification Req...|In order to apply...|                  null|"Click the ""Appl...|35 Hours per week...|96-05 Horace Hard...|                null| New York City res...|2013-12-20T00:00:...|                null|2014-07-25T00:00:...|2019-08-20T00:00:...|
          Annual|75 Park Place New...|  Financial Services|DoITT provides fo...|     "Qualification Re...| acquired with th...|   as described in ...|               ""2""| or ""3"" above. ...| from an accredit...| for six months o...|  all candidates m...|  mid-range computer| and/or LAN or WA...| acquired within ...| in the areas of ...|
# |172053|DEPT OF INFO TECH...|    Internal|             1|311 Call Center M...|ADM MANAGER-NON-M...|        1002C|    0|Community & Busin...|                            F|            49492|          69000|          Annual|      59 Maiden Lane|      311 Operations|DoITT provides fo...|     "1. A baccalaurea...| 18 months of whi...|            managerial| executive or sup...| full-time progre...| 18 months of whi...|          managerial|   executive or su...| ""2"" or ""3"" a...| all  candidates ...|          managerial| executive or sup...|
# +------+--------------------+------------+--------------+--------------------+--------------------+-------------+-----+--------------------+-----------------------------+-----------------+---------------+----------------+--------------------+--------------------+--------------------+-------------------------+--------------------+----------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# #### 1.1. How many jobs do we have in the dataset?

# %%
allJobs = df.count()
print("All rows in database: ", allJobs )
# Out:
# All rows in database:  3228

# %% [markdown]
# #### 1.2. How many distinct job title do we have in the dataset?

# %%
uniqueJobs = df.select('Business Title').distinct().count()
print("Total n. of distinct job titles: ", uniqueJobs)
# Out:
# Total n. of distinct job titles:  1326

# %%
# Take only columns necessary to the project
df1 = df[["Job ID", "Agency", "# Of Positions", "Business Title", "Job Category", "Full-Time/Part-Time indicator", "Salary Range From", "Salary Range To", "Work Location", "Job Description", "Minimum Qual Requirements", "Preferred Skills", "Additional Information"]]
df1.show()
# Out:
# +------+--------------------+--------------+--------------------+--------------------+-----------------------------+-----------------+---------------+--------------------+--------------------+-------------------------+--------------------+----------------------+
# |Job ID|              Agency|# Of Positions|      Business Title|        Job Category|Full-Time/Part-Time indicator|Salary Range From|Salary Range To|       Work Location|     Job Description|Minimum Qual Requirements|    Preferred Skills|Additional Information|
# +------+--------------------+--------------+--------------------+--------------------+-----------------------------+-----------------+---------------+--------------------+--------------------+-------------------------+--------------------+----------------------+
# | 87990|DEPARTMENT OF BUS...|             1|     Account Manager|                null|                         null|            42405|          65485| 110 William St. N Y|Division of Econo...|     "1.	A baccalaurea...| all candidates m...|  â€¢	Excellent int...|
# | 97899|DEPARTMENT OF BUS...|             1|EXECUTIVE DIRECTO...|                null|                            F|            60740|         162014| 110 William St. N Y|The New York City...|     "1. A baccalaurea...|                null|                  null|
# |132292|NYC HOUSING AUTHO...|            52|Maintenance Worke...|Maintenance & Ope...|                            F|         51907.68|       54580.32|Heating Mgt-Opera...|Under direct supe...|     "1. Three years o...|          mechanical|   or construction ...|
# |132292|NYC HOUSING AUTHO...|            52|Maintenance Worke...|Maintenance & Ope...|                            F|         51907.68|       54580.32|Heating Mgt-Opera...|Under direct supe...|     "1. Three years o...|          mechanical|   or construction ...|
# |133921|NYC HOUSING AUTHO...|            50|   Temporary Painter|Maintenance & Ope...|                            F|               35|             35|DMP-Contract & An...|Responsibilities ...|     1. Five years of ...|                null|  SPECIAL NOTE:    ...|
# |133921|NYC HOUSING AUTHO...|            50|   Temporary Painter|Maintenance & Ope...|                            F|               35|             35|DMP-Contract & An...|Responsibilities ...|     1. Five years of ...|                null|  SPECIAL NOTE:    ...|
# |137433|DEPT OF HEALTH/ME...|             1|    Contract Analyst|Finance, Accounti...|                            F|            50598|          85053|   42-09 28th Street|** OPEN TO PERMAN...|     "1. A baccalaurea...| individuals must...|   after meeting th...|
# |138531|DEPT OF ENVIRONME...|             1|   Associate Chemist|Health Public Saf...|                            F|            50623|          75083|96-05 Horace Hard...|Working in the Di...|     Qualification Req...|In order to apply...|                  null|
# |151131|NYC HOUSING AUTHO...|             1|Cost Estimating M...|Engineering, Arch...|                            F|            90000|         110000|CP Cap Plan-Techn...|Reporting to the ...|     "1. A master's de...| including the 18...|            managerial|
# |151937|NYC HOUSING AUTHO...|             4|Assistant Project...|Engineering, Arch...|                            F|            62942|          92249|Office for Exec P...|The Assistant Pro...|     "One year of full...| candidates must ...|  1.  Five (5) plus...|
# |151937|NYC HOUSING AUTHO...|             4|Assistant Project...|Engineering, Arch...|                            F|            62942|          92249|Office for Exec P...|The Assistant Pro...|     "One year of full...| candidates must ...|  1.  Five (5) plus...|
# |152738|      LAW DEPARTMENT|             1|      Office Manager|Clerical & Admini...|                            F|            30683|          49707|100 Church St., N.Y.|Performs essentia...|     Qualification Req...|Experience with L...|  Candidates must b...|
# |160910|DEPT OF INFO TECH...|             1|Deputy Director, ...|Finance, Accounti...|                            F|            49492|          60000|75 Park Place New...|DoITT provides fo...|     "1. A baccalaurea...| 18 months of whi...|            managerial|
# |167179|NYC EMPLOYEES RET...|             1|CERTIFIED IT ADMI...|Information Techn...|                            F|            87203|         131623|335 Adams Street,...|Oversees the desi...|     "1. A baccalaurea...| all candidates m...|  Minimum 5 years o...|
# |167179|NYC EMPLOYEES RET...|             1|CERTIFIED IT ADMI...|Information Techn...|                            F|            87203|         131623|335 Adams Street,...|Oversees the desi...|     "1. A baccalaurea...| all candidates m...|  Minimum 5 years o...|
# |170989|OFFICE OF COLLECT...|             1|COLLEGE AIDE - CL...|Clerical & Admini...|                            P|             8.75|          10.36|     100 Gold Street|The Office of Col...|     For Assignment Le...|1.	Excellent inte...|                  null|
# |170989|OFFICE OF COLLECT...|             1|COLLEGE AIDE - CL...|Clerical & Admini...|                            P|             8.75|          10.36|     100 Gold Street|The Office of Col...|     For Assignment Le...|1.	Excellent inte...|                  null|
# |171040|DEPT OF HEALTH/ME...|             1|Clerical Associat...|Clerical & Admini...|                            F|            32086|          51981|   42-09 28th Street|** OPEN TO PERMAN...|     Qualification Req...|-	Good writing an...|                  null|
# |171944|DEPT OF INFO TECH...|             1|Deputy Director, ...|Finance, Accounti...|                         null|            43292|          53000|75 Park Place New...|DoITT provides fo...|     "Qualification Re...| acquired with th...|   as described in ...|
# |172053|DEPT OF INFO TECH...|             1|311 Call Center M...|Community & Busin...|                            F|            49492|          69000|      59 Maiden Lane|DoITT provides fo...|     "1. A baccalaurea...| 18 months of whi...|            managerial|
# +------+--------------------+--------------+--------------------+--------------------+-----------------------------+-----------------+---------------+--------------------+--------------------+-------------------------+--------------------+----------------------+
# only showing top 20 rows

# %% [markdown]
# #### 1.3. Fix some wrong data types

# %%
# Next we make sure that numerical columns are in type integer
from pyspark.sql.types import *
df1 = df1.withColumn("Salary Range From", df1["Salary Range From"].cast(IntegerType()))
df1 = df1.withColumn("Salary Range To", df1["Salary Range To"].cast(IntegerType()))
df1 = df1.withColumn("# Of Positions", df1["# Of Positions"].cast(IntegerType()))

# %%
# Change to pandas dataframe for easy visualization
df_p = df1.toPandas()
df_p.shape
# Out:
# (3228, 13)

# %% [markdown]
# #### 1.4. How many positions available for each job?

# %%
# Visualization on number of postions for each job
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

vacancies = df_p.groupby('Business Title')['# Of Positions'].sum().sort_values(ascending=False).head(15)
vacancies = vacancies.reset_index()

plt.figure(figsize=(20,10))
plt.bar(vacancies['Business Title'], vacancies['# Of Positions'], color='green')
plt.xticks(vacancies['Business Title'], rotation=60)
plt.show()

# %% [markdown]
# #### 1.5. What are the highest paid jobs in the dataset?

# %%
# Highest salary jobs
salaries = df_p.groupby('Business Title')['Salary Range To'].mean().sort_values(ascending=False).head(15)
salaries = salaries.reset_index()

plt.figure(figsize=(20,10))
plt.barh(salaries['Business Title'], salaries['Salary Range To'], color='red')
plt.yticks(salaries['Business Title'])
plt.show()

# %%
# Install wordcloud
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Using cached https://files.pythonhosted.org/packages/ae/af/849edf14d573eba9c8082db898ff0d090428d9485371cc4fe21a66717ad2/wordcloud-1.5.0-cp36-cp36m-manylinux1_x86_64.whl
# Collecting numpy>=1.6.1 (from wordcloud)
#   Using cached https://files.pythonhosted.org/packages/e5/e6/c3fdc53aed9fa19d6ff3abf97dfad768ae3afce1b7431f7500000816bda5/numpy-1.17.2-cp36-cp36m-manylinux1_x86_64.whl
# Collecting pillow (from wordcloud)
#   Using cached https://files.pythonhosted.org/packages/14/41/db6dec65ddbc176a59b89485e8cc136a433ed9c6397b6bfe2cd38412051e/Pillow-6.1.0-cp36-cp36m-manylinux1_x86_64.whl
# tensorflow 1.13.1 requires tensorboard<1.14.0,>=1.13.0, which is not installed.
# Installing collected packages: numpy, pillow, wordcloud
# Successfully installed numpy-1.17.2 pillow-6.1.0 wordcloud-1.5.0
# Target directory /home/spark/shared/user-libs/python3.6/wordcloud already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/Pillow-6.1.0.dist-info already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/numpy already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/numpy-1.17.2.dist-info already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/wordcloud-1.5.0.dist-info already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/PIL already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/bin already exists. Specify --upgrade to force replacement.

# %% [markdown]
# #### 1.6. What qualifications and skills do most jobs require?

# %%
# Find the most occuring qualification and skill
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
stopwords = set(STOPWORDS)
stopwords.update(["english"])

# Generate a word cloud image
plt.figure(figsize=(15, 10))
wordcloud = WordCloud(stopwords=stopwords, background_color="white", max_words=150).generate_from_text(str(df_p['Minimum Qual Requirements']))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

plt.figure(figsize=(15, 10))
wordcloud = WordCloud(stopwords=stopwords, background_color="white", colormap="rainbow", max_words=150).generate_from_text(str(df_p['Preferred Skills']))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### 2. Data Cleaning and Feature Engineering

# %% [markdown]
# #### 2.1. Create ETL, and upload the nyc-jobs.csv file to Cloud Object Storage

# %%
credentials = {

   "apikey": "oDF5lYbLsLQXa8RMBtucTdeT3g3yXGRYa9H3rJXBUltC",
   "cos_hmac_keys": {
    "access_key_id": "38428cff313d4390a5766378a14f9830", 
    "secret_access_key": "e77e2857559e362dc4231e72a7aec17e2ed5a8e935a5cb79"
   },
   "endpoints": "https://s3.us.cloud-object-storage.appdomain.cloud",
   "iam_apikey_description": "Auto-generated for key 38428cff-313d-4390-a576-6378a14f9830",
   "iam_apikey_name": "Service credentials-1",
   "iam_role_crn": "crn:v1:bluemix:public:iam::::serviceRole:Manager",
   "iam_serviceid_crn": "crn:v1:bluemix:public:iam-identity::a/39ab347da12e4d838644458813bd22dd::serviceid:ServiceId-5d306231-6364-4926-b25a-2d9394d33d4f",
  "resource_instance_id": "crn:v1:bluemix:public:cloud-object-storage:global:a/39ab347da12e4d838644458813bd22dd:abc5e98f-41d3-49c9-a285-c321a1be779c::"
}

# %%
endpoint = 'https://s3.us.cloud-object-storage.appdomain.cloud'

# %%
bucket_name = 'advanceddatasciencewithibm-donotdelete-pr-ix96rnitjjpbid'

# %%
from ibm_botocore.client import Config
import ibm_boto3 as boto3

# %%
resource = boto3.resource(
    's3',
    aws_access_key_id = credentials["cos_hmac_keys"]['access_key_id'],
    aws_secret_access_key = credentials["cos_hmac_keys"]["secret_access_key"],
    endpoint_url = endpoint,
)

# %%
client = boto3.client(
    's3',
    aws_access_key_id = credentials["cos_hmac_keys"]['access_key_id'],
    aws_secret_access_key = credentials["cos_hmac_keys"]["secret_access_key"],
    endpoint_url=endpoint,

)

# %%
client.upload_file(Filename='nyc-jobs.csv',Bucket=bucket_name,Key='nyc-jobs_data.csv')

# %% [markdown]
# #### 2.2. Drop the column with unformatted data

# %%
# Next we observe the work location column has none address formatted entries
# However I don't have access to Google or Foursquare API, therefore I don't know the exact address of each location
# Since the entire dataset was about job postings within New York City, I have decided to drop the work location column
df1 = df1.drop('Work Location')

# %% [markdown]
# #### 2.3. Imputing some missing data

# %%
# Notice here that there are missing values
# Majority of missing values are not numerical, therefore I won't be able to impute them
# In addition, I cannot drop all missing values either since, it will reduce the dataset drastically
# However, I can impute the missing value for Full-Time/Part-Time indicator column

from pyspark.sql.functions import when

df1 = df1.withColumn("Full-Time/Part-Time indicator", \
              when(df1["Salary Range From"] > 2000, "F").otherwise(df1["Full-Time/Part-Time indicator"]))

df1 = df1.withColumn("Full-Time/Part-Time indicator", \
              when(df1["Salary Range From"] < 2000, "P").otherwise(df1["Full-Time/Part-Time indicator"]))

# %% [markdown]
# #### 2.4. Fix some wrong data types again

# %%
df1 = df1.withColumn("Minimum Qual Requirements", df1["Minimum Qual Requirements"].cast(StringType()))
df1 = df1.withColumn("Preferred Skills", df1["Preferred Skills"].cast(StringType()))

# %%
df1.show()
# Out:
# +------+--------------------+--------------+--------------------+--------------------+-----------------------------+-----------------+---------------+--------------------+-------------------------+--------------------+----------------------+
# |Job ID|              Agency|# Of Positions|      Business Title|        Job Category|Full-Time/Part-Time indicator|Salary Range From|Salary Range To|     Job Description|Minimum Qual Requirements|    Preferred Skills|Additional Information|
# +------+--------------------+--------------+--------------------+--------------------+-----------------------------+-----------------+---------------+--------------------+-------------------------+--------------------+----------------------+
# | 87990|DEPARTMENT OF BUS...|             1|     Account Manager|                null|                            F|            42405|          65485|Division of Econo...|     "1.	A baccalaurea...| all candidates m...|  â€¢	Excellent int...|
# | 97899|DEPARTMENT OF BUS...|             1|EXECUTIVE DIRECTO...|                null|                            F|            60740|         162014|The New York City...|     "1. A baccalaurea...|                null|                  null|
# |132292|NYC HOUSING AUTHO...|            52|Maintenance Worke...|Maintenance & Ope...|                            F|            51907|          54580|Under direct supe...|     "1. Three years o...|          mechanical|   or construction ...|
# |132292|NYC HOUSING AUTHO...|            52|Maintenance Worke...|Maintenance & Ope...|                            F|            51907|          54580|Under direct supe...|     "1. Three years o...|          mechanical|   or construction ...|
# |133921|NYC HOUSING AUTHO...|            50|   Temporary Painter|Maintenance & Ope...|                            P|               35|             35|Responsibilities ...|     1. Five years of ...|                null|  SPECIAL NOTE:    ...|
# |133921|NYC HOUSING AUTHO...|            50|   Temporary Painter|Maintenance & Ope...|                            P|               35|             35|Responsibilities ...|     1. Five years of ...|                null|  SPECIAL NOTE:    ...|
# |137433|DEPT OF HEALTH/ME...|             1|    Contract Analyst|Finance, Accounti...|                            F|            50598|          85053|** OPEN TO PERMAN...|     "1. A baccalaurea...| individuals must...|   after meeting th...|
# |138531|DEPT OF ENVIRONME...|             1|   Associate Chemist|Health Public Saf...|                            F|            50623|          75083|Working in the Di...|     Qualification Req...|In order to apply...|                  null|
# |151131|NYC HOUSING AUTHO...|             1|Cost Estimating M...|Engineering, Arch...|                            F|            90000|         110000|Reporting to the ...|     "1. A master's de...| including the 18...|            managerial|
# |151937|NYC HOUSING AUTHO...|             4|Assistant Project...|Engineering, Arch...|                            F|            62942|          92249|The Assistant Pro...|     "One year of full...| candidates must ...|  1.  Five (5) plus...|
# |151937|NYC HOUSING AUTHO...|             4|Assistant Project...|Engineering, Arch...|                            F|            62942|          92249|The Assistant Pro...|     "One year of full...| candidates must ...|  1.  Five (5) plus...|
# |152738|      LAW DEPARTMENT|             1|      Office Manager|Clerical & Admini...|                            F|            30683|          49707|Performs essentia...|     Qualification Req...|Experience with L...|  Candidates must b...|
# |160910|DEPT OF INFO TECH...|             1|Deputy Director, ...|Finance, Accounti...|                            F|            49492|          60000|DoITT provides fo...|     "1. A baccalaurea...| 18 months of whi...|            managerial|
# |167179|NYC EMPLOYEES RET...|             1|CERTIFIED IT ADMI...|Information Techn...|                            F|            87203|         131623|Oversees the desi...|     "1. A baccalaurea...| all candidates m...|  Minimum 5 years o...|
# |167179|NYC EMPLOYEES RET...|             1|CERTIFIED IT ADMI...|Information Techn...|                            F|            87203|         131623|Oversees the desi...|     "1. A baccalaurea...| all candidates m...|  Minimum 5 years o...|
# |170989|OFFICE OF COLLECT...|             1|COLLEGE AIDE - CL...|Clerical & Admini...|                            P|                8|             10|The Office of Col...|     For Assignment Le...|1.	Excellent inte...|                  null|
# |170989|OFFICE OF COLLECT...|             1|COLLEGE AIDE - CL...|Clerical & Admini...|                            P|                8|             10|The Office of Col...|     For Assignment Le...|1.	Excellent inte...|                  null|
# |171040|DEPT OF HEALTH/ME...|             1|Clerical Associat...|Clerical & Admini...|                            F|            32086|          51981|** OPEN TO PERMAN...|     Qualification Req...|-	Good writing an...|                  null|
# |171944|DEPT OF INFO TECH...|             1|Deputy Director, ...|Finance, Accounti...|                            F|            43292|          53000|DoITT provides fo...|     "Qualification Re...| acquired with th...|   as described in ...|
# |172053|DEPT OF INFO TECH...|             1|311 Call Center M...|Community & Busin...|                            F|            49492|          69000|DoITT provides fo...|     "1. A baccalaurea...| 18 months of whi...|            managerial|
# +------+--------------------+--------------+--------------------+--------------------+-----------------------------+-----------------+---------------+--------------------+-------------------------+--------------------+----------------------+
# only showing top 20 rows

# %% [markdown]
# #### 2.5. Split the columns with multiple strings into keywords separated by comma

# %%
# Now we do some feature engineering
# I would like to separete each requirement in minimum qual requirements column and preferred skills column and put them in one-hot encoding
# However, it seems to be impossible for this project because
# 1. the values are saparated by a mix of punctuation marks rather than commas
# 2. The number of string values in the column for each job is not the same
# What I will do here is to split them by semicolons and put them in a single list
from pyspark.sql.functions import split

df_qual = df1.withColumn("Minimum Qual Requirements", split("Minimum Qual Requirements", " "))

df_skill = df_qual.withColumn("Preferred Skills", split("Preferred Skills", " "))

# %% [markdown]
# #### 2.6. Extract the seemingly correlated columns and compute its correlation

# %%
# Focus on the minimum qual requirements and preferred skills columns
df_cor = df_skill[['Business Title', 'Salary Range From', 'Minimum Qual Requirements', 'Preferred Skills']]
df_cor.show()
# Out:
# +--------------------+-----------------+-------------------------+--------------------+
# |      Business Title|Salary Range From|Minimum Qual Requirements|    Preferred Skills|
# +--------------------+-----------------+-------------------------+--------------------+
# |     Account Manager|            42405|     ["1.	A, baccalaur...|[, all, candidate...|
# |EXECUTIVE DIRECTO...|            60740|     ["1., A, baccalau...|                null|
# |Maintenance Worke...|            51907|     ["1., Three, year...|      [, mechanical]|
# |Maintenance Worke...|            51907|     ["1., Three, year...|      [, mechanical]|
# |   Temporary Painter|               35|     [1., Five, years,...|                null|
# |   Temporary Painter|               35|     [1., Five, years,...|                null|
# |    Contract Analyst|            50598|     ["1., A, baccalau...|[, individuals, m...|
# |   Associate Chemist|            50623|     [Qualification, R...|[In, order, to, a...|
# |Cost Estimating M...|            90000|     ["1., A, master's...|[, including, the...|
# |Assistant Project...|            62942|     ["One, year, of, ...|[, candidates, mu...|
# |Assistant Project...|            62942|     ["One, year, of, ...|[, candidates, mu...|
# |      Office Manager|            30683|     [Qualification, R...|[Experience, with...|
# |Deputy Director, ...|            49492|     ["1., A, baccalau...|[, 18, months, of...|
# |CERTIFIED IT ADMI...|            87203|     ["1., A, baccalau...|[, all, candidate...|
# |CERTIFIED IT ADMI...|            87203|     ["1., A, baccalau...|[, all, candidate...|
# |COLLEGE AIDE - CL...|                8|     [For, Assignment,...|[1.	Excellent, in...|
# |COLLEGE AIDE - CL...|                8|     [For, Assignment,...|[1.	Excellent, in...|
# |Clerical Associat...|            32086|     [Qualification, R...|[-	Good, writing,...|
# |Deputy Director, ...|            43292|     ["Qualification, ...|[, acquired, with...|
# |311 Call Center M...|            49492|     ["1., A, baccalau...|[, 18, months, of...|
# +--------------------+-----------------+-------------------------+--------------------+
# only showing top 20 rows

# %%
# Count number of values in the minimum qual requirements column
from pyspark.sql.functions import size
cor1 = df_cor.select('*',size('Minimum Qual Requirements').alias('Qual Count'))

# Count number of values in the preferred skills column
cor2 = cor1.select('*',size('Preferred Skills').alias('Skills Count'))
cor2.show()
# Out:
# +--------------------+-----------------+-------------------------+--------------------+----------+------------+
# |      Business Title|Salary Range From|Minimum Qual Requirements|    Preferred Skills|Qual Count|Skills Count|
# +--------------------+-----------------+-------------------------+--------------------+----------+------------+
# |     Account Manager|            42405|     ["1.	A, baccalaur...|[, all, candidate...|        71|          16|
# |EXECUTIVE DIRECTO...|            60740|     ["1., A, baccalau...|                null|       140|          -1|
# |Maintenance Worke...|            51907|     ["1., Three, year...|      [, mechanical]|        63|           2|
# |Maintenance Worke...|            51907|     ["1., Three, year...|      [, mechanical]|        63|           2|
# |   Temporary Painter|               35|     [1., Five, years,...|                null|        69|          -1|
# |   Temporary Painter|               35|     [1., Five, years,...|                null|        69|          -1|
# |    Contract Analyst|            50598|     ["1., A, baccalau...|[, individuals, m...|       213|           4|
# |   Associate Chemist|            50623|     [Qualification, R...|[In, order, to, a...|       201|          78|
# |Cost Estimating M...|            90000|     ["1., A, master's...|[, including, the...|       187|           7|
# |Assistant Project...|            62942|     ["One, year, of, ...|[, candidates, mu...|       333|          40|
# |Assistant Project...|            62942|     ["One, year, of, ...|[, candidates, mu...|       333|          40|
# |      Office Manager|            30683|     [Qualification, R...|[Experience, with...|        53|           8|
# |Deputy Director, ...|            49492|     ["1., A, baccalau...|[, 18, months, of...|        98|          11|
# |CERTIFIED IT ADMI...|            87203|     ["1., A, baccalau...|[, all, candidate...|        98|          23|
# |CERTIFIED IT ADMI...|            87203|     ["1., A, baccalau...|[, all, candidate...|        98|          23|
# |COLLEGE AIDE - CL...|                8|     [For, Assignment,...|[1.	Excellent, in...|       234|          18|
# |COLLEGE AIDE - CL...|                8|     [For, Assignment,...|[1.	Excellent, in...|       234|          18|
# |Clerical Associat...|            32086|     [Qualification, R...|[-	Good, writing,...|        53|          39|
# |Deputy Director, ...|            43292|     ["Qualification, ...|[, acquired, with...|       101|           7|
# |311 Call Center M...|            49492|     ["1., A, baccalau...|[, 18, months, of...|        98|          11|
# +--------------------+-----------------+-------------------------+--------------------+----------+------------+
# only showing top 20 rows

# %%
# There are obvious data loss, since the preferred skills column has size -1
# Find correlations between salary and qual requirements/skills
# For some reason, I cannot get the matrix to display in correct format, ie. 3x3 
from pyspark.ml.stat import Correlation
from pyspark.ml.feature import VectorAssembler
from pyspark.mllib.util import MLUtils
from pyspark.ml.feature import Normalizer

assembler = VectorAssembler(inputCols=["Salary Range From", "Qual Count", "Skills Count"], outputCol="vector_col")
assembled = assembler.transform(cor2).select('vector_col')
matrix = Correlation.corr(assembled, 'vector_col')
matrix.collect()[0]["pearson({})".format('vector_col')].values
# Out:
# array([ 1.        , -0.00607311,  0.16031597, -0.00607311,  1.        ,
#        -0.08789125,  0.16031597, -0.08789125,  1.        ])

# %% [markdown]
# ### 3. Model Training With Machine Learning

# %%
# !pip install rake_nltk
# Out:
# Collecting rake_nltk
# Collecting nltk (from rake_nltk)
# Collecting six (from nltk->rake_nltk)
#   Using cached https://files.pythonhosted.org/packages/73/fb/00a976f728d0d1fecfe898238ce23f502a721c0ac0ecfedb80e0d88c64e9/six-1.12.0-py2.py3-none-any.whl
# tensorflow 1.13.1 requires tensorboard<1.14.0,>=1.13.0, which is not installed.
# Installing collected packages: six, nltk, rake-nltk
# Successfully installed nltk-3.4.5 rake-nltk-1.0.4 six-1.12.0
# Target directory /home/spark/shared/user-libs/python3.6/six.py already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/rake_nltk-1.0.4.dist-info already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/nltk-3.4.5.dist-info already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/six-1.12.0.dist-info already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/__pycache__ already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/rake_nltk already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/nltk already exists. Specify --upgrade to force replacement.

# %%
import pandas as pd
from rake_nltk import Rake
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
model_df = df[["Job ID", "Business Title", "Job Description", "Minimum Qual Requirements", "Preferred Skills"]]

# %%
from pyspark.sql import functions as C

# %% [markdown]
# #### 3.1. Group some interested columns into one

# %%
model_df1 = model_df.withColumn('Joined Column', 
                    C.concat(C.col('Business Title'), C.lit(' '), C.col('Job Description'), C.lit(' '), C.col('Minimum Qual Requirements'), C.lit(' '), C.col('Preferred Skills')))
model_df1.show()
# Out:
# +------+--------------------+--------------------+-------------------------+--------------------+--------------------+
# |Job ID|      Business Title|     Job Description|Minimum Qual Requirements|    Preferred Skills|       Joined Column|
# +------+--------------------+--------------------+-------------------------+--------------------+--------------------+
# | 87990|     Account Manager|Division of Econo...|     "1.	A baccalaurea...| all candidates m...|Account Manager D...|
# | 97899|EXECUTIVE DIRECTO...|The New York City...|     "1. A baccalaurea...|                null|                null|
# |132292|Maintenance Worke...|Under direct supe...|     "1. Three years o...|          mechanical|Maintenance Worke...|
# |132292|Maintenance Worke...|Under direct supe...|     "1. Three years o...|          mechanical|Maintenance Worke...|
# |133921|   Temporary Painter|Responsibilities ...|     1. Five years of ...|                null|                null|
# |133921|   Temporary Painter|Responsibilities ...|     1. Five years of ...|                null|                null|
# |137433|    Contract Analyst|** OPEN TO PERMAN...|     "1. A baccalaurea...| individuals must...|Contract Analyst ...|
# |138531|   Associate Chemist|Working in the Di...|     Qualification Req...|In order to apply...|Associate Chemist...|
# |151131|Cost Estimating M...|Reporting to the ...|     "1. A master's de...| including the 18...|Cost Estimating M...|
# |151937|Assistant Project...|The Assistant Pro...|     "One year of full...| candidates must ...|Assistant Project...|
# |151937|Assistant Project...|The Assistant Pro...|     "One year of full...| candidates must ...|Assistant Project...|
# |152738|      Office Manager|Performs essentia...|     Qualification Req...|Experience with L...|Office Manager Pe...|
# |160910|Deputy Director, ...|DoITT provides fo...|     "1. A baccalaurea...| 18 months of whi...|Deputy Director, ...|
# |167179|CERTIFIED IT ADMI...|Oversees the desi...|     "1. A baccalaurea...| all candidates m...|CERTIFIED IT ADMI...|
# |167179|CERTIFIED IT ADMI...|Oversees the desi...|     "1. A baccalaurea...| all candidates m...|CERTIFIED IT ADMI...|
# |170989|COLLEGE AIDE - CL...|The Office of Col...|     For Assignment Le...|1.	Excellent inte...|COLLEGE AIDE - CL...|
# |170989|COLLEGE AIDE - CL...|The Office of Col...|     For Assignment Le...|1.	Excellent inte...|COLLEGE AIDE - CL...|
# |171040|Clerical Associat...|** OPEN TO PERMAN...|     Qualification Req...|-	Good writing an...|Clerical Associat...|
# |171944|Deputy Director, ...|DoITT provides fo...|     "Qualification Re...| acquired with th...|Deputy Director, ...|
# |172053|311 Call Center M...|DoITT provides fo...|     "1. A baccalaurea...| 18 months of whi...|311 Call Center M...|
# +------+--------------------+--------------------+-------------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# #### 3.2. Convert into pandas dataframe for modeling

# %%
# Not sure how to add the desired column in spark dataframe 
# Here I will briefly convert it to pandas dataframe
model_dfp = model_df1.toPandas()

# %%
model_dfp["Joined Column"] = model_dfp["Joined Column"].astype(str)

# %%
# Fix Business Title column string format
# Capitalize only on first letter of each word
model_dfp['Business Title'] = model_dfp['Business Title'].str.title()
model_dfp["Joined Column"] = model_dfp["Joined Column"].str.title()
model_dfp.head()
# Out:
#    Job ID                                     Business Title  \
# 0   87990                                    Account Manager
# 1   97899           Executive Director, Business Development
# 2  132292  Maintenance Worker - Technical Services-Heatin...
# 3  132292  Maintenance Worker - Technical Services-Heatin...
# 4  133921                                  Temporary Painter
#
#                                      Job Description  \
# 0  Division of Economic & Financial Opportunity (...
# 1  The New York City Department of Small Business...
# 2  Under direct supervision, assist in the routin...
# 3  Under direct supervision, assist in the routin...
# 4  Responsibilities of selected candidates will i...
#
#                            Minimum Qual Requirements  \
# 0  "1.\tA baccalaureate degree from an accredited...
# 1  "1. A baccalaureate degree from an accredited ...
# 2  "1. Three years of full-time satisfactory expe...
# 3  "1. Three years of full-time satisfactory expe...
# 4  1. Five years of full-time satisfactory experi...
#
#                                     Preferred Skills  \
# 0   all candidates must have at least one year of...
# 1                                               None
# 2                                         mechanical
# 3                                         mechanical
# 4                                               None
#
#                                        Joined Column
# 0  Account Manager Division Of Economic & Financi...
# 1                                               None
# 2  Maintenance Worker - Technical Services-Heatin...
# 3  Maintenance Worker - Technical Services-Heatin...
# 4                                               None

# %% [markdown]
# #### 3.3. Extract keywords

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/spark/shared/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/spark/shared/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Initializing the new column
model_dfp['keyWords'] = ""

for index, row in model_dfp.iterrows():
    keyword = row['Joined Column']
    
    # Instantiating Rake, by default it uses english stopwords from NLTK and discards all puntuation characters as well
    r = Rake()

    # Extracting the words by passing the text
    r.extract_keywords_from_text(keyword)

    # Getting the dictionary with key words as keys and their scores as values
    key_words_dict_scores = r.get_word_degrees()
    
    # Assigning the key words to the new column
    row['keyWords'] = list(key_words_dict_scores.keys())

# Dropping the Joined Column
model_dfp.drop(columns = ['Joined Column'], inplace = True)

# %%
model_dfp.drop_duplicates(subset = "Business Title", inplace=True)

# %%
model_dfp.set_index('Business Title', inplace = True)

# %%
model_dfp.head()
# Out:
#                                                     Job ID  \
# Business Title
# Account Manager                                      87990
# Executive Director, Business Development             97899
# Maintenance Worker - Technical Services-Heating...  132292
# Temporary Painter                                   133921
# Contract Analyst                                    137433
#
#                                                                                       Job Description  \
# Business Title
# Account Manager                                     Division of Economic & Financial Opportunity (...
# Executive Director, Business Development            The New York City Department of Small Business...
# Maintenance Worker - Technical Services-Heating...  Under direct supervision, assist in the routin...
# Temporary Painter                                   Responsibilities of selected candidates will i...
# Contract Analyst                                    ** OPEN TO PERMANENT PROCUREMENT ANALYSTS ONLY...
#
#                                                                             Minimum Qual Requirements  \
# Business Title
# Account Manager                                     "1.\tA baccalaureate degree from an accredited...
# Executive Director, Business Development            "1. A baccalaureate degree from an accredited ...
# Maintenance Worker - Technical Services-Heating...  "1. Three years of full-time satisfactory expe...
# Temporary Painter                                   1. Five years of full-time satisfactory experi...
# Contract Analyst                                    "1. A baccalaureate degree from an accredited ...
#
#                                                                                      Preferred Skills  \
# Business Title
# Account Manager                                      all candidates must have at least one year of...
# Executive Director, Business Development                                                         None
# Maintenance Worker - Technical Services-Heating...                                         mechanical
# Temporary Painter                                                                                None
# Contract Analyst                                                                individuals must have
#
#                                                                                              keyWords
# Business Title
# Account Manager                                     [defo, women, method, new, york, cityâ, €™, do...
# Executive Director, Business Development                                                       [none]
# Maintenance Worker - Technical Services-Heating...  [4, 6, helper, technical, services, public, bu...
# Temporary Painter                                                                              [none]
# Contract Analyst                                    [4, housing, infected, persons, grants, experi...

# %%
model_dfp1 = model_dfp[['Job ID', 'keyWords']]
model_dfp1.head()
# Out:
#                                                     Job ID  \
# Business Title
# Account Manager                                      87990
# Executive Director, Business Development             97899
# Maintenance Worker - Technical Services-Heating...  132292
# Temporary Painter                                   133921
# Contract Analyst                                    137433
#
#                                                                                              keyWords
# Business Title
# Account Manager                                     [defo, women, method, new, york, cityâ, €™, do...
# Executive Director, Business Development                                                       [none]
# Maintenance Worker - Technical Services-Heating...  [4, 6, helper, technical, services, public, bu...
# Temporary Painter                                                                              [none]
# Contract Analyst                                    [4, housing, infected, persons, grants, experi...

# %%
model_dfp1['keyWords'] = model_dfp1['keyWords'].apply(', '.join)
model_dfp1.head()
# Out:
# /opt/ibm/conda/miniconda3.6/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                                     Job ID  \
# Business Title
# Account Manager                                      87990
# Executive Director, Business Development             97899
# Maintenance Worker - Technical Services-Heating...  132292
# Temporary Painter                                   133921
# Contract Analyst                                    137433
#
#                                                                                              keyWords
# Business Title
# Account Manager                                     defo, women, method, new, york, cityâ, €™, dol...
# Executive Director, Business Development                                                         none
# Maintenance Worker - Technical Services-Heating...  4, 6, helper, technical, services, public, bui...
# Temporary Painter                                                                                none
# Contract Analyst                                    4, housing, infected, persons, grants, experie...

# %% [markdown]
# #### 3.4. Training using TfidfVectorizer

# %%
tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 3), min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(model_dfp1['keyWords'])

# %%
# Generating the cosine similarity matrix
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
cosine_sim
# Out:
# array([[1.        , 0.        , 0.00524873, ..., 0.01481167, 0.01069173,
#         0.00824411],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.00524873, 0.        , 1.        , ..., 0.00464727, 0.00686126,
#         0.0048529 ],
#        ...,
#        [0.01481167, 0.        , 0.00464727, ..., 1.        , 0.01961393,
#         0.01341139],
#        [0.01069173, 0.        , 0.00686126, ..., 0.01961393, 1.        ,
#         0.01110431],
#        [0.00824411, 0.        , 0.0048529 , ..., 0.01341139, 0.01110431,
#         1.        ]])

# %% [markdown]
# #### 3.5. Recommending and Performance Evaluation

# %%
# Creating a Series for the job titles so they are associated to an ordered numerical list I will use in the function to match the indexes
indices = pd.Series(model_dfp1.index)

# Defining the function that takes in business title as input and returns the top 10 recommended jobs
def recommendations(title, cosine_sim = cosine_sim):
    
    # Initializing the empty list of recommended jobs
    recommended_jobs = []
    
    # Gettin the index of the job that matches the title
    idx = indices[indices == title].index[0]

    # Creating a Series with the similarity scores in descending order
    score_series = pd.Series(cosine_sim[idx]).sort_values(ascending = False)

    # Getting the indexes of the 10 most similar jobs
    top_10_indexes = list(score_series.iloc[0:10].index)
    
    # populating the list with the titles of the best 10 matching jobs
    for i in top_10_indexes:
        recommended_jobs.append(list(model_dfp1.index)[i])
        
    return recommended_jobs

# %%
# Test the recommender system
recommendations("Computer Programmer")
# Out:
# ['Computer Programmer',
#  'Gis Analyst',
#  'E-Learning Content Developer (Per Diem)',
#  'E-Learning Content Developer',
#  '.Net Programmer / Analyst',
#  'Application Support Reporting Specialist',
#  'Body Worn Camera Analyst',
#  'Mipp/Tphi Software Developer',
#  'Cyber Data Engineer',
#  'Dynamic Crm Developer']

# %%
model_dfp1.iloc[model_dfp1.index.get_loc('Gis Analyst')]['keyWords']
# Out:
# 'complexity, option, proficient, cartography, esri, planning, enterprise, geodatabase, equivalent, among, â, €¢, maintenance, end, user, help, desk, experience, working, users, human, services, city, life, microsoft, office, suite, candidates, editors, education, emergency, communications, transformation, program, demanding, projects, minimal, supervision, full, spectrum, doitt, schools, least, addresses, 625, hours, responsibilities, performance, centralized, database, businesses, perform, special, new, york, oral, communication, skills, sustained, 100, feature, classes, year, related, computer, field, scale, esriâ, €™, represented, able, attempt, team, environment, educational, employees, twenty, transit, infrastructure, 24, 60, graduate, school, satisfactory, combination, data, entry, response, agencies, using, python, projections, cscl, 2, application, development, management, division, geospatial, custom, tools, within, automated, quality, assurance, checks, technology, leader, manual, possess, interoperability, extension, may, coordination, assigned, versioned, sixty, unacceptable, foundational, detail, oriented, internally, 1, accredited, college, fulltime, programming, geography, initiatives, operations, support, retrieval, serve, governmental, well, enhance, service, delivery, public, safety, four, high, diploma, daily, administrative, tasks, specific, supplemented, qualify, gis, analyst, provides, successful, candidate, arcgis, desktop, software, equated, baccalaureate, degree, telecommunications, work, alone, advanced, maintaining, ectp, reporting, engineering, must, editing, technical, areas, contains, model, builder, unique, private, facilities, including, credits, however, residents, tables, system, edit, required, strong, written, years, systems, coordinate, post, one, effective, substituted, multi, responsible, semester, proven, ability, time, economic, crossing, examples, teaching, efficient, principles, certificate, include, basis, science, qa, );, hardware, installation, intended, touch, every, aspect, plus, topology, following, streets, similar, visitors, 3, package, back, products, addition'

# %%
# Some testing codes
model_dfp1.iloc[model_dfp1.index.get_loc('Gis Analyst')]['keyWords']
matches=len(set(model_dfp1.iloc[model_dfp1.index.get_loc('Payroll Associate')]['keyWords']) & set(model_dfp1.iloc[model_dfp1.index.get_loc('Temporary Painter')]['keyWords']))
matches
# Out:
# 3

# %%
# Performance Evaluation
# Due to the nature of this project, performance evaluation will be based on relevancy levels, namely the accuracy
# Here I will define the metric to be the averge number of matching keywords of recommended jobs compare to the input job
from statistics import mean 
def accuracy(title):
    matches = []
    for job in recommendations(title):
        matches.append(len(set(model_dfp1.iloc[model_dfp1.index.get_loc(job)]['keyWords']) & set(model_dfp1.iloc[model_dfp1.index.get_loc(title)]['keyWords'])))
# 0.9048780487804878
# 1.0
# 0.865909090909091
# 0.9583333333333334
# 0.9574999999999999
# 0.962857142857143
# 1.0
# 0.9567567567567568
# 0.9823529411764705
# 0.9813953488372094
# 0.993103448275862
# 1.0
# 0.9542857142857143
# 0.9538461538461539
# 0.9303030303030303
# 0.9076923076923077
# 1.0
# 0.9128205128205129
# 0.991891891891892
# 1.0
# 0.9868421052631579
# 0.9285714285714286
# 1.0
# 0.9216216216216216
# 0.927906976744186
# 0.9102564102564102
# 0.9555555555555556
# 0.9317073170731708
# 0.9617647058823531
# 0.9416666666666667
# 0.9405405405405405
# 0.9564102564102563
# 0.9641025641025641
# 0.9684210526315788
# 0.9837837837837837
# 0.96875
# 0.9210526315789473
# 0.9542857142857143
# 0.8810810810810811
# 0.9058823529411765
# 0.9351351351351351
# 1.0
# 0.9641025641025641
# 0.9361111111111112
# 0.95
# 0.9444444444444444
# 0.9261904761904761
# 0.8953488372093024
# 0.9724999999999999
# 0.9574999999999999
# 0.8804878048780488

# %% [markdown]
# #### 3.6. Possible improvements

# %%
# I suspect that change all value to lowercase 
# Remove all punctuations except comma
# Remove all digits will likely to increase performace of this model
# This is due to the fact that it will simply match the keywords more precisely

# %% [markdown]
# ### 4. Model Training With Deep Learning

# %%
# I suspect that using all lower case letter will probably increase performace

# %% [markdown]
# #### 4.1. Combine columns into one

# %%
# Tried to use same setting on all keywords
# One-hot encoding will crash due to too many keywords
# Instead spliting joined column into keywords, I will split only the business title and job descrpition and minimum qual requirements columns
from pyspark.sql.functions import initcap
model_df = model_df.withColumn("Business Title", initcap("Business Title"))
model_df = model_df.withColumn("Job Description", initcap("Job Description"))
model_df = model_df.withColumn("Minimum Qual Requirements", initcap("Minimum Qual Requirements"))
model_df.show()
# Out:
# +------+--------------------+--------------------+-------------------------+--------------------+
# |Job ID|      Business Title|     Job Description|Minimum Qual Requirements|    Preferred Skills|
# +------+--------------------+--------------------+-------------------------+--------------------+
# | 87990|     Account Manager|Division Of Econo...|     "1.	a Baccalaurea...| all candidates m...|
# | 97899|Executive Directo...|The New York City...|     "1. A Baccalaurea...|                null|
# |132292|Maintenance Worke...|Under Direct Supe...|     "1. Three Years O...|          mechanical|
# |132292|Maintenance Worke...|Under Direct Supe...|     "1. Three Years O...|          mechanical|
# |133921|   Temporary Painter|Responsibilities ...|     1. Five Years Of ...|                null|
# |133921|   Temporary Painter|Responsibilities ...|     1. Five Years Of ...|                null|
# |137433|    Contract Analyst|** Open To Perman...|     "1. A Baccalaurea...| individuals must...|
# |138531|   Associate Chemist|Working In The Di...|     Qualification Req...|In order to apply...|
# |151131|Cost Estimating M...|Reporting To The ...|     "1. A Master's De...| including the 18...|
# |151937|Assistant Project...|The Assistant Pro...|     "one Year Of Full...| candidates must ...|
# |151937|Assistant Project...|The Assistant Pro...|     "one Year Of Full...| candidates must ...|
# |152738|      Office Manager|Performs Essentia...|     Qualification Req...|Experience with L...|
# |160910|Deputy Director, ...|Doitt Provides Fo...|     "1. A Baccalaurea...| 18 months of whi...|
# |167179|Certified It Admi...|Oversees The Desi...|     "1. A Baccalaurea...| all candidates m...|
# |167179|Certified It Admi...|Oversees The Desi...|     "1. A Baccalaurea...| all candidates m...|
# |170989|College Aide - Cl...|The Office Of Col...|     For Assignment Le...|1.	Excellent inte...|
# |170989|College Aide - Cl...|The Office Of Col...|     For Assignment Le...|1.	Excellent inte...|
# |171040|Clerical Associat...|** Open To Perman...|     Qualification Req...|-	Good writing an...|
# |171944|Deputy Director, ...|Doitt Provides Fo...|     "qualification Re...| acquired with th...|
# |172053|311 Call Center M...|Doitt Provides Fo...|     "1. A Baccalaurea...| 18 months of whi...|
# +------+--------------------+--------------------+-------------------------+--------------------+
# only showing top 20 rows

# %%
model_df2 = model_df.withColumn('Joint', 
                    C.concat(C.col('Business Title'), C.lit(' '), C.col('Job Description'), C.lit(' '), C.col('Minimum Qual Requirements')))
model_df2.show()
# Out:
# +------+--------------------+--------------------+-------------------------+--------------------+--------------------+
# |Job ID|      Business Title|     Job Description|Minimum Qual Requirements|    Preferred Skills|               Joint|
# +------+--------------------+--------------------+-------------------------+--------------------+--------------------+
7.\tproduce  Analysis Of Agency Contracts And M/wbe Program Performance   8.\tcoordinate Resources For Agencies As Necessary, Including Networking Events, Training Sessions, Etc. "1.\ta Baccalaureate Degree From An Accredited College And Two Years Of Experience In Community Work Or Community Centered Activities In An Area Related To The Duties Described Above; Or  2.\thigh School Graduation Or Equivalent And Six Years Of Experience In Community Work Or Community Centered Activities In An Area Related To The Duties As Described Above; Or  3.\teducation And/or Experience Which Is Equivalent To ""1"" Or ""2"" Above. However'

# %%
model_df2p = model_df2.toPandas()

# %%
model_df2p.head()
# Out:
#    Job ID                                     Business Title  \
# 0   87990                                    Account Manager
# 1   97899           Executive Director, Business Development
# 2  132292  Maintenance Worker - Technical Services-heatin...
# 3  132292  Maintenance Worker - Technical Services-heatin...
# 4  133921                                  Temporary Painter
#
#                                      Job Description  \
# 0  Division Of Economic & Financial Opportunity (...
# 1  The New York City Department Of Small Business...
# 2  Under Direct Supervision, Assist In The Routin...
# 3  Under Direct Supervision, Assist In The Routin...
# 4  Responsibilities Of Selected Candidates Will I...
#
#                            Minimum Qual Requirements  \
# 0  "1.\ta Baccalaureate Degree From An Accredited...
# 1  "1. A Baccalaureate Degree From An Accredited ...
# 2  "1. Three Years Of Full-time Satisfactory Expe...
# 3  "1. Three Years Of Full-time Satisfactory Expe...
# 4  1. Five Years Of Full-time Satisfactory Experi...
#
#                                     Preferred Skills  \
# 0   all candidates must have at least one year of...
# 1                                               None
# 2                                         mechanical
# 3                                         mechanical
# 4                                               None
#
#                                                Joint
# 0  Account Manager Division Of Economic & Financi...
# 1  Executive Director, Business Development The N...
# 2  Maintenance Worker - Technical Services-heatin...
# 3  Maintenance Worker - Technical Services-heatin...
# 4  Temporary Painter Responsibilities Of Selected...

# %%
model_df2p["Joint"] = model_df2p["Joint"].astype(str)

# %% [markdown]
# #### 4.2. Remove all punctuations and numbers

# %%
import string
from string import digits

def remove_punctuations(text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')
    return text

def remove_numbers(text):
    for number in digits:
        text = text.replace(number, '')
    return text

# %%
model_df2p["Joint"] = model_df2p["Joint"].apply(remove_punctuations)
model_df2p["Joint"] = model_df2p["Joint"].apply(remove_numbers)

# %%
model_df3p = model_df2p[['Business Title', 'Joint']]
model_df3p.head()
# Out:
#                                       Business Title  \
# 0                                    Account Manager
# 1           Executive Director, Business Development
# 2  Maintenance Worker - Technical Services-heatin...
# 3  Maintenance Worker - Technical Services-heatin...
# 4                                  Temporary Painter
#
#                                                Joint
# 0  Account Manager Division Of Economic  Financia...
# 1  Executive Director Business Development The Ne...
# 2  Maintenance Worker  Technical Servicesheating ...
# 3  Maintenance Worker  Technical Servicesheating ...
# 4  Temporary Painter Responsibilities Of Selected...

# %%
# Replace space with comma
model_df3p['Joint'] = model_df3p['Joint'].apply(lambda x: x.replace(' ',','))
# Out:
# /opt/ibm/conda/miniconda3.6/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
model_df3p.head()
# Out:
#                                       Business Title  \
# 0                                    Account Manager
# 1           Executive Director, Business Development
# 2  Maintenance Worker - Technical Services-heatin...
# 3  Maintenance Worker - Technical Services-heatin...
# 4                                  Temporary Painter
#
#                                                Joint
# 0  Account,Manager,Division,Of,Economic,,Financia...
# 1  Executive,Director,Business,Development,The,Ne...
# 2  Maintenance,Worker,,Technical,Servicesheating,...
# 3  Maintenance,Worker,,Technical,Servicesheating,...
# 4  Temporary,Painter,Responsibilities,Of,Selected...

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.utils import np_utils
from keras.preprocessing.text import Tokenizer
from keras import metrics

from pprint import pprint
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
# Out:
# Using TensorFlow backend.
# /opt/ibm/conda/miniconda3.6/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/ibm/conda/miniconda3.6/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/ibm/conda/miniconda3.6/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/ibm/conda/miniconda3.6/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/ibm/conda/miniconda3.6/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/ibm/conda/miniconda3.6/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# #### 4.3. Split data to train and test

# %%
train, test = train_test_split(model_df3p, test_size = 0.2)

train_Title = train['Business Title']
train_Joint = train['Joint']

test_Title = test['Business Title']
test_Joint = test['Joint']

print(len(model_df3p['Business Title'].unique().tolist()))
print(len(model_df3p['Joint'].unique().tolist()))

print(len(train_Joint.unique().tolist()))
print(len(test_Joint.unique().tolist()))
# Out:
# 1282
# 1739
# 1618
# 575

# %%
num_labels = len(train_Title.unique().tolist())
vocab_size = 1000
batch_size = 32
nb_epoch = 30

tokenizer = Tokenizer(num_words=vocab_size)
tokenizer.fit_on_texts(train_Joint)
 
x_train = tokenizer.texts_to_matrix(train_Joint, mode='tfidf')
x_test = tokenizer.texts_to_matrix(test_Joint, mode='tfidf')
 
encoder = LabelBinarizer()
encoder.fit(train_Title)
y_train = encoder.transform(train_Title)
y_test = encoder.transform(test_Title)

# %% [markdown]
# #### 4.4. Define model

# %%
model = Sequential()
model.add(Dense(512, input_shape=(vocab_size,)))
model.add(Activation('relu'))
model.add(Dropout(0.3))
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.3))
model.add(Dense(num_labels))
model.add(Activation('softmax'))
model.summary()
 
model.compile(loss = 'categorical_crossentropy',
              optimizer = 'adam',
              metrics = [metrics.categorical_accuracy, 'accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 512)               512512
# _________________________________________________________________
# activation_4 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               262656
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1193)              612009
# _________________________________________________________________
# activation_6 (Activation)    (None, 1193)              0
# =================================================================
# Total params: 1,387,177
# Trainable params: 1,387,177
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=nb_epoch,
                    verbose=1,
                    validation_split=0.1)
# Out:
# Train on 2323 samples, validate on 259 samples
# Epoch 1/30
# 2323/2323 [==============================] - 3s 1ms/step - loss: 6.7702 - categorical_accuracy: 0.0598 - acc: 0.0598 - val_loss: 6.1126 - val_categorical_accuracy: 0.1351 - val_acc: 0.1351
# Epoch 2/30
# 2323/2323 [==============================] - 2s 680us/step - loss: 4.5367 - categorical_accuracy: 0.2622 - acc: 0.2622 - val_loss: 4.7335 - val_categorical_accuracy: 0.2741 - val_acc: 0.2741
# Epoch 3/30
# 2323/2323 [==============================] - 2s 681us/step - loss: 2.1734 - categorical_accuracy: 0.5889 - acc: 0.5889 - val_loss: 3.5087 - val_categorical_accuracy: 0.5212 - val_acc: 0.5212
# Epoch 4/30
# 2323/2323 [==============================] - 2s 693us/step - loss: 1.0835 - categorical_accuracy: 0.7598 - acc: 0.7598 - val_loss: 3.1457 - val_categorical_accuracy: 0.6216 - val_acc: 0.6216
# Epoch 5/30
# 2323/2323 [==============================] - 2s 653us/step - loss: 0.6706 - categorical_accuracy: 0.8480 - acc: 0.8480 - val_loss: 3.1057 - val_categorical_accuracy: 0.6602 - val_acc: 0.6602
# Epoch 6/30
# 2323/2323 [==============================] - 2s 687us/step - loss: 0.5099 - categorical_accuracy: 0.8773 - acc: 0.8773 - val_loss: 3.1307 - val_categorical_accuracy: 0.6834 - val_acc: 0.6834
# Epoch 7/30
# 2323/2323 [==============================] - 2s 648us/step - loss: 0.1997 - categorical_accuracy: 0.9458 - acc: 0.9458 - val_loss: 3.3530 - val_categorical_accuracy: 0.6950 - val_acc: 0.6950
# Epoch 22/30
# 2323/2323 [==============================] - 2s 661us/step - loss: 0.2044 - categorical_accuracy: 0.9488 - acc: 0.9488 - val_loss: 3.2817 - val_categorical_accuracy: 0.7027 - val_acc: 0.7027
# Epoch 23/30
# 2323/2323 [==============================] - 2s 696us/step - loss: 0.1925 - categorical_accuracy: 0.9539 - acc: 0.9539 - val_loss: 3.3862 - val_categorical_accuracy: 0.7027 - val_acc: 0.7027
# Epoch 24/30
# 2323/2323 [==============================] - 2s 659us/step - loss: 0.1918 - categorical_accuracy: 0.9458 - acc: 0.9458 - val_loss: 3.4030 - val_categorical_accuracy: 0.6950 - val_acc: 0.6950
# Epoch 25/30
# 2323/2323 [==============================] - 2s 663us/step - loss: 0.1787 - categorical_accuracy: 0.9518 - acc: 0.9518 - val_loss: 3.4513 - val_categorical_accuracy: 0.7104 - val_acc: 0.7104
# Epoch 26/30
# 2323/2323 [==============================] - 2s 678us/step - loss: 0.2109 - categorical_accuracy: 0.9475 - acc: 0.9475 - val_loss: 3.3860 - val_categorical_accuracy: 0.6988 - val_acc: 0.6988
# Epoch 27/30
# 2323/2323 [==============================] - 2s 660us/step - loss: 0.1831 - categorical_accuracy: 0.9531 - acc: 0.9531 - val_loss: 3.5352 - val_categorical_accuracy: 0.6950 - val_acc: 0.6950
# Epoch 28/30
# 2323/2323 [==============================] - 2s 665us/step - loss: 0.1819 - categorical_accuracy: 0.9496 - acc: 0.9496 - val_loss: 3.4781 - val_categorical_accuracy: 0.6873 - val_acc: 0.6873
# Epoch 29/30
# 2323/2323 [==============================] - 2s 692us/step - loss: 0.1976 - categorical_accuracy: 0.9496 - acc: 0.9496 - val_loss: 3.4271 - val_categorical_accuracy: 0.7027 - val_acc: 0.7027
# Epoch 30/30
# 2323/2323 [==============================] - 2s 669us/step - loss: 0.1851 - categorical_accuracy: 0.9505 - acc: 0.9505 - val_loss: 3.4188 - val_categorical_accuracy: 0.6988 - val_acc: 0.6988

# %% [markdown]
# #### 4.5. Evaluation metrics

# %%
score = model.evaluate(x_test, y_test,
                       batch_size=batch_size, verbose=1)
 
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 646/646 [==============================] - 0s 100us/step
# Test loss: 1.179626505819184
# Test accuracy: 0.6749226006191951

# %% [markdown]
# #### 4.6.  Improve our model

# %%
train, test = train_test_split(model_df3p, test_size = 0.2)

train_Title = train['Business Title']
train_Joint = train['Joint']

test_Title = test['Business Title']
test_Joint = test['Joint']

print(len(model_df3p['Business Title'].unique().tolist()))
print(len(model_df3p['Joint'].unique().tolist()))

print(len(train_Joint.unique().tolist()))
print(len(test_Joint.unique().tolist()))
# Out:
# 1282
# 1739
# 1614
# 584

# %%
num_labels = len(train_Title.unique().tolist())
vocab_size = 1000
batch_size = 32
nb_epoch = 50

tokenizer = Tokenizer(num_words=vocab_size)
tokenizer.fit_on_texts(train_Joint)
 
x_train = tokenizer.texts_to_matrix(train_Joint, mode='tfidf')
x_test = tokenizer.texts_to_matrix(test_Joint, mode='tfidf')
 
encoder = LabelBinarizer()
encoder.fit(train_Title)
y_train = encoder.transform(train_Title)
y_test = encoder.transform(test_Title)

# %%
model = Sequential()
model.add(Dense(4096, input_shape=(vocab_size,), activation = 'relu', kernel_initializer = 'glorot_normal', kernel_constraint=maxnorm(2)))
model.add(Dropout(0.1))
model.add(Dense(1024, kernel_initializer = 'glorot_normal', activation= 'relu'))
model.add(Dropout(0.1))
model.add(Dense(num_labels))
model.add(Activation('softmax'))
    
model.compile(loss = 'categorical_crossentropy',
              optimizer = 'sgd',
              metrics = [metrics.categorical_accuracy, 'accuracy'])

# %%
report = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=nb_epoch,
                    verbose=1,
                    validation_split=0.1)
# Out:
# Train on 2323 samples, validate on 259 samples
# Epoch 1/50
# 2323/2323 [==============================] - 6s 3ms/step - loss: 7.0114 - categorical_accuracy: 0.0185 - acc: 0.0185 - val_loss: 6.8195 - val_categorical_accuracy: 0.0425 - val_acc: 0.0425
# Epoch 2/50
# 2323/2323 [==============================] - 5s 2ms/step - loss: 6.4917 - categorical_accuracy: 0.0740 - acc: 0.0740 - val_loss: 6.5442 - val_categorical_accuracy: 0.0888 - val_acc: 0.0888
# Epoch 3/50
# 2323/2323 [==============================] - 5s 2ms/step - loss: 5.9924 - categorical_accuracy: 0.1154 - acc: 0.1154 - val_loss: 6.2891 - val_categorical_accuracy: 0.1274 - val_acc: 0.1274
# Epoch 4/50
# 2323/2323 [==============================] - 5s 2ms/step - loss: 5.4893 - categorical_accuracy: 0.1851 - acc: 0.1851 - val_loss: 6.0684 - val_categorical_accuracy: 0.1622 - val_acc: 0.1622
# Epoch 5/50
# 2323/2323 [==============================] - 5s 2ms/step - loss: 4.9655 - categorical_accuracy: 0.2678 - acc: 0.2678 - val_loss: 5.8123 - val_categorical_accuracy: 0.1931 - val_acc: 0.1931
# Epoch 6/50
# 2323/2323 [==============================] - 5s 2ms/step - loss: 4.4347 - categorical_accuracy: 0.3633 - acc: 0.3633 - val_loss: 5.5926 - val_categorical_accuracy: 0.2085 - val_acc: 0.2085
# Epoch 7/50
# 2323/2323 [==============================] - 4s 2ms/step - loss: 3.9207 - categorical_accuracy: 0.4671 - acc: 0.4671 - val_loss: 5.3892 - val_categorical_accuracy: 0.2432 - val_acc: 0.2432
# Epoch 8/50
# 2323/2323 [==============================] - 5s 2ms/step - loss: 3.4310 - categorical_accuracy: 0.5562 - acc: 0.5562 - val_loss: 5.1829 - val_categorical_accuracy: 0.2703 - val_acc: 0.2703
# Epoch 9/50
# 2323/2323 [==============================] - 5s 2ms/step - loss: 2.9882 - categorical_accuracy: 0.6233 - acc: 0.6233 - val_loss: 4.9534 - val_categorical_accuracy: 0.3359 - val_acc: 0.3359
# Epoch 10/50
# 2323/2323 [==============================] - 5s 2ms/step - loss: 2.5828 - categorical_accuracy: 0.6789 - acc: 0.6789 - val_loss: 4.7410 - val_categorical_accuracy: 0.3745 - val_acc: 0.3745
# Epoch 11/50
# 2323/2323 [==============================] - 5s 2ms/step - loss: 2.2234 - categorical_accuracy: 0.7202 - acc: 0.7202 - val_loss: 4.5362 - val_categorical_accuracy: 0.4363 - val_acc: 0.4363
# Epoch 12/50
# 2323/2323 [==============================] - 5s 2ms/step - loss: 1.8964 - categorical_accuracy: 0.7602 - acc: 0.7602 - val_loss: 4.3694 - val_categorical_accuracy: 0.4942 - val_acc: 0.4942
# Epoch 13/50
# 2323/2323 [==============================] - 5s 2ms/step - loss: 1.6407 - categorical_accuracy: 0.7861 - acc: 0.7861 - val_loss: 4.2196 - val_categorical_accuracy: 0.5212 - val_acc: 0.5212
# Epoch 14/50
# 2323/2323 [==============================] - 5s 2ms/step - loss: 1.4283 - categorical_accuracy: 0.8149 - acc: 0.8149 - val_loss: 4.0683 - val_categorical_accuracy: 0.5714 - val_acc: 0.5714
# Epoch 15/50
# 2323/2323 [==============================] - 5s 2ms/step - loss:
50
# 2323/2323 [==============================] - 5s 2ms/step - loss: 0.2080 - categorical_accuracy: 0.9643 - acc: 0.9643 - val_loss: 3.7894 - val_categorical_accuracy: 0.6371 - val_acc: 0.6371
# Epoch 39/50
# 2323/2323 [==============================] - 4s 2ms/step - loss: 0.1905 - categorical_accuracy: 0.9656 - acc: 0.9656 - val_loss: 3.8124 - val_categorical_accuracy: 0.6371 - val_acc: 0.6371
# Epoch 40/50
# 2323/2323 [==============================] - 5s 2ms/step - loss: 0.1904 - categorical_accuracy: 0.9660 - acc: 0.9660 - val_loss: 3.8096 - val_categorical_accuracy: 0.6448 - val_acc: 0.6448
# Epoch 41/50
# 2323/2323 [==============================] - 5s 2ms/step - loss: 0.1830 - categorical_accuracy: 0.9686 - acc: 0.9686 - val_loss: 3.7985 - val_categorical_accuracy: 0.6486 - val_acc: 0.6486
# Epoch 42/50
# 2323/2323 [==============================] - 5s 2ms/step - loss: 0.1788 - categorical_accuracy: 0.9660 - acc: 0.9660 - val_loss: 3.8089 - val_categorical_accuracy: 0.6448 - val_acc: 0.6448
# Epoch 43/50
# 2323/2323 [==============================] - 5s 2ms/step - loss: 0.1738 - categorical_accuracy: 0.9694 - acc: 0.9694 - val_loss: 3.8248 - val_categorical_accuracy: 0.6332 - val_acc: 0.6332
# Epoch 44/50
# 2323/2323 [==============================] - 4s 2ms/step - loss: 0.1701 - categorical_accuracy: 0.9703 - acc: 0.9703 - val_loss: 3.8411 - val_categorical_accuracy: 0.6409 - val_acc: 0.6409
# Epoch 45/50
# 2323/2323 [==============================] - 5s 2ms/step - loss: 0.1617 - categorical_accuracy: 0.9690 - acc: 0.9690 - val_loss: 3.8373 - val_categorical_accuracy: 0.6409 - val_acc: 0.6409
# Epoch 46/50
# 2323/2323 [==============================] - 5s 2ms/step - loss: 0.1601 - categorical_accuracy: 0.9712 - acc: 0.9712 - val_loss: 3.8309 - val_categorical_accuracy: 0.6409 - val_acc: 0.6409
# Epoch 47/50
# 2323/2323 [==============================] - 4s 2ms/step - loss: 0.1607 - categorical_accuracy: 0.9681 - acc: 0.9681 - val_loss: 3.8378 - val_categorical_accuracy: 0.6409 - val_acc: 0.6409
# Epoch 48/50
# 2323/2323 [==============================] - 4s 2ms/step - loss: 0.1502 - categorical_accuracy: 0.9750 - acc: 0.9750 - val_loss: 3.8227 - val_categorical_accuracy: 0.6486 - val_acc: 0.6486
# Epoch 49/50
# 2323/2323 [==============================] - 4s 2ms/step - loss: 0.1529 - categorical_accuracy: 0.9681 - acc: 0.9681 - val_loss: 3.8409 - val_categorical_accuracy: 0.6293 - val_acc: 0.6293
# Epoch 50/50
# 2323/2323 [==============================] - 5s 2ms/step - loss: 0.1434 - categorical_accuracy: 0.9729 - acc: 0.9729 - val_loss: 3.8329 - val_categorical_accuracy: 0.6448 - val_acc: 0.6448

# %%
score = model.evaluate(x_test, y_test,
                       batch_size=batch_size, verbose=1)
 
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 646/646 [==============================] - 0s 403us/step
# Test loss: 0.9361288374053436
# Test accuracy: 0.7554179568408812

# %%
print(report.history.keys())
# Out:
# dict_keys(['val_loss', 'val_categorical_accuracy', 'val_acc', 'loss', 'categorical_accuracy', 'acc'])

# %%
plt.plot(report.history['acc'])
plt.plot(report.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(report.history['loss'])
plt.plot(report.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# As shown in the plots we can see as epoch increases, the accuracy increases and stabilizes around 50 epochs
# This increased the model performace fairly but not extensively
# This project is yet to be finished

# %% [markdown]
# ### 5. References

# %% [markdown]
# #### https://heartbeat.fritz.ai/recommender-systems-with-python-part-i-content-based-filtering-5df4940bd831
# #### https://towardsdatascience.com/creating-a-hybrid-content-collaborative-movie-recommender-using-deep-learning-cc8b431618af
# #### https://www.datacamp.com/community/tutorials/recommender-systems-python
